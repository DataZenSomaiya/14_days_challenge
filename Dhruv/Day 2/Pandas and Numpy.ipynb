# %%
import pandas as pd
import numpy as np

# %%
PANDAS

# %%
df = pd.read_csv('C:\\Users\\Dhruv\\PycharmProjects\\MW-Preopen-Market.csv')

# %%
df
# Out:
#      SYMBOL \n PREV. CLOSE \n IEP  PRICE \n CHNG \n %CHNG \n FINAL PRICE \n  \
# 0    COALINDIA         232.70        232.95    0.25     0.11         232.95
# 1         NTPC         168.45        168.50    0.05     0.03         168.50
# 2    NESTLEIND      19,041.90     19,041.90       -        -      19,041.90
# 3   HINDUNILVR       2,573.10      2,571.80   -1.30    -0.05       2,571.80
# 4   ASIANPAINT       3,395.25      3,392.00   -3.25    -0.10       3,392.00
# 5   BAJAJFINSV      16,968.95     16,950.00  -18.95    -0.11      16,950.00
# 6     DIVISLAB       3,585.50      3,577.00   -8.50    -0.24       3,577.00
# 7    BRITANNIA       3,608.80      3,600.00   -8.80    -0.24       3,600.00
# 8         BPCL         324.25        323.35   -0.90    -0.28         323.35
# 9          UPL         738.10        736.05   -2.05    -0.28         736.05
# 10      MARUTI       8,888.75      8,864.00  -24.75    -0.28       8,864.00
# 11    SHREECEM      21,654.35     21,580.00  -74.35    -0.34      21,580.00
# 12         ITC         327.15        326.00   -1.15    -0.35         326.00
# 13  BAJAJ-AUTO       3,929.40      3,915.00  -14.40    -0.37       3,915.00
# 14  ADANIPORTS         850.35        847.00   -3.35    -0.39         847.00
# 15  TATACONSUM         818.25        815.00   -3.25    -0.40         815.00
# 16  ULTRACEMCO       6,495.50      6,460.00  -35.50    -0.55       6,460.00
# 17     SBILIFE       1,311.35      1,304.00   -7.35    -0.56       1,304.00
# 18     DRREDDY       4,239.20      4,215.00  -24.20    -0.57       4,215.00
# 19   ICICIBANK         883.65        878.55   -5.10    -0.58         878.55
# 20  BAJFINANCE       7,119.35      7,078.00  -41.35    -0.58       7,078.00
# 21       WIPRO         404.45        402.10   -2.35    -0.58         402.10
# 22    HDFCLIFE         573.50        570.00   -3.50    -0.61         570.00
# 23        SBIN         537.80        534.40   -3.40    -0.63         534.40
# 24       CIPLA       1,040.85      1,033.85   -7.00    -0.67       1,033.85
# 25  BHARTIARTL         761.25        755.50   -5.75    -0.76         755.50
# 26      GRASIM       1,723.05      1,710.00  -13.05    -0.76       1,710.00
# 27         TCS       3,127.05      3,102.00  -25.05    -0.80       3,102.00
# 28   KOTAKBANK       1,915.70      1,900.00  -15.70    -0.82       1,900.00
# 29  APOLLOHOSP       4,415.50      4,379.20  -36.30    -0.82       4,379.20
# 30        ONGC         132.10        131.00   -1.10    -0.83         131.00
# 31    RELIANCE       2,596.85      2,575.00  -21.85    -0.84       2,575.00
# 32   POWERGRID         225.05        223.05   -2.00    -0.89         223.05
# 33    AXISBANK         750.00        743.15   -6.85    -0.91         743.15
# 34  HEROMOTOCO       2,866.55      2,840.00  -26.55    -0.93       2,840.00
# 35   SUNPHARMA         887.75        879.50   -8.25    -0.93         879.50
# 36       TITAN       2,631.65      2,607.00  -24.65    -0.94       2,607.00
# 37    JSWSTEEL         684.55        678.00   -6.55    -0.96         678.00
# 38   TATASTEEL         108.60        107.55   -1.05    -0.97         107.55
# 39  TATAMOTORS         457.75        453.20   -4.55    -0.99         453.20
# 38             345360   37,143,468.00    875,965,988,636.64      147.60
# 39              58559   26,538,938.80    820,879,708,852.98      536.70
# 40              34198   49,245,120.00  5,326,359,395,820.05    1,953.90
# 41               6001   11,648,541.10  2,371,292,161,764.74    2,078.55
# 42              33370   80,822,140.00  4,435,769,669,312.00    3,021.10
# 43               5226    5,497,752.00    672,336,314,908.12    1,838.00
# 44              10705    9,923,535.00    992,501,299,541.23    1,377.75
# 45              13950   18,009,450.00  1,250,562,189,400.83    1,330.65
# 46              77594  114,164,052.20  6,533,407,894,715.78    1,725.00
# 47               3493    3,824,835.00    721,829,212,606.66    1,242.00
# 48               1958    6,580,250.60    475,568,923,563.28    3,513.70
# 49              46299   19,642,350.75    629,472,405,515.07      636.00
#
#    NM 52W L \n
# 0       139.15
# 1       112.40
# 2    16,000.00
# 3     1,901.55
# 4     2,560.00
# 5    10,727.20
# 6     3,365.55
# 7     3,050.00
# 8       293.35
# 9       607.50
# 10    6,536.55
# 11   17,865.20
# 12      207.00
# 13    3,027.05
# 14      651.95
# 15      650.20
# 16    5,157.05
# 17    1,003.50
# 18    3,654.00
# 19      642.15
# 20    5,220.00
# 21      391.00
# 22      497.05
# 23      425.00
# 24      850.00
# 25      628.75
# 26    1,276.60
# 27    2,953.00
# 28    1,631.00
# 29    3,361.55
# 30      117.50
# 31    2,180.00
# 32      170.20
# 33      618.25
# 34    2,146.85
# 35      733.70
# 36    1,825.05
# 37      520.05
# 38       82.70
# 39      290.90
# 40    1,367.15
# 41    1,456.35
# 42    2,026.00
# 43      943.70
# 44      877.35
# 45      671.15
# 46    1,271.60
# 47      763.20
# 48    2,159.55
# 49      308.95

# %%
rows, columns = df.shape
print('rows',rows)
print('columns',columns)
# Out:
# rows 50
# columns 11

# %%
print(df.head(7))

print(df.tail(5))
# Out:
#     SYMBOL \n PREV. CLOSE \n IEP  PRICE \n CHNG \n %CHNG \n FINAL PRICE \n  \
# 0   COALINDIA         232.70        232.95    0.25     0.11         232.95
# 1        NTPC         168.45        168.50    0.05     0.03         168.50
# 2   NESTLEIND      19,041.90     19,041.90       -        -      19,041.90
# 3  HINDUNILVR       2,573.10      2,571.80   -1.30    -0.05       2,571.80
# 4  ASIANPAINT       3,395.25      3,392.00   -3.25    -0.10       3,392.00
# 5  BAJAJFINSV      16,968.95     16,950.00  -18.95    -0.11      16,950.00
# 6    DIVISLAB       3,585.50      3,577.00   -8.50    -0.24       3,577.00
#
#    FINAL QUANTITY \n         VALUE               FFM CAP  NM 52W H \n  \
# 0              36704   8,550,196.80    487,582,739,775.59      236.80
# 1             197619  33,298,801.50    800,367,671,033.43      168.85
# 2                111   2,113,650.90    679,297,216,325.15   20,609.15
# 3               6386  16,423,514.80  2,297,378,644,975.84    2,859.30
# 4               3788  12,848,896.00  1,530,656,659,353.83    3,590.00
# 5               1955  33,137,250.00  1,026,150,225,538.24   19,325.00
# 6               1005   3,594,885.00    456,882,044,923.20    5,425.10
#
#   NM 52W L \n
# 0      139.15
# 1      112.40
# 2   16,000.00
# 3    1,901.55
# 4    2,560.00
# 5   10,727.20
# 6    3,365.55
#      SYMBOL \n PREV. CLOSE \n IEP  PRICE \n CHNG \n %CHNG \n FINAL PRICE \n  \
# 45         M&M       1,306.40      1,291.00  -15.40    -1.18       1,291.00
# 46    HDFCBANK       1,489.35      1,471.30  -18.05    -1.21       1,471.30
# 47  INDUSINDBK       1,108.80      1,095.00  -13.80    -1.24       1,095.00
# 48   EICHERMOT       3,410.35      3,360.70  -49.65    -1.46       3,360.70
# 49    HINDALCO         430.95        424.25   -6.70    -1.55         424.25
#
#     FINAL QUANTITY \n          VALUE               FFM CAP  NM 52W H \n  \
# 45              13950   18,009,450.00  1,250,562,189,400.83    1,330.65
# 46              77594  114,164,052.20  6,533,407,894,715.78    1,725.00
# 47               3493    3,824,835.00    721,829,212,606.66    1,242.00
# 48               1958    6,580,250.60    475,568,923,563.28    3,513.70
# 49              46299   19,642,350.75    629,472,405,515.07      636.00
#
#    NM 52W L \n
# 45      671.15
# 46    1,271.60
# 47      763.20
# 48    2,159.55
# 49      308.95

# %%
print(df.iloc[0])
print(df.iloc[1,1:3])
# Out:
# SYMBOL \n                     COALINDIA
# PREV. CLOSE \n                   232.70
# IEP  PRICE \n                    232.95
# CHNG \n                            0.25
# %CHNG \n                           0.11
# FINAL PRICE \n                   232.95
# FINAL QUANTITY \n                 36704
# VALUE                      8,550,196.80
# FFM CAP              487,582,739,775.59
# NM 52W H \n                      236.80
# NM 52W L \n                      139.15
# Name: 0, dtype: object
# PREV. CLOSE \n    168.45
# IEP  PRICE \n     168.50
# Name: 1, dtype: object

# %%
df.describe()
# Out:
#        FINAL QUANTITY \n
# count          50.000000
# mean        30817.000000
# std         58510.227288
# min           111.000000
# 25%          2383.000000
# 50%          7586.000000
# 75%         36077.500000
# max        345360.000000

# %%
NUMPY.
# Out:
#   Input In [2]
#     NUMPY.
#           ^
# SyntaxError: invalid syntax

# %%
arr1 = np.array([[4.0,6.0,5.0,8.0,2.0,8.4,9.0,6.5,4.3],[3.7,6.0,9.7,8.5,4.9]])
print(arr1)

arr2 = np.array([[7.0,2.0,3.0,2.0,13.2,4.5],[5.0,2.0,1.0]], dtype =object)
print(arr2)
# Out:
# [[4.  6.  5.  8.  2. ]
#  [3.7 6.  9.7 8.5 4.9]]
# [list([7.0, 2.0, 3.0, 2.0, 9.0, 10.0, 13.2, 4.5]) list([5.0, 2.0, 1.0])]

# %%
print('Dimension of Array 1-',arr1.ndim)
print('Dimension of Array 2-',arr2.ndim)
# Out:
# Dimension of Array 1- 2
# Dimension of Array 2- 1

# %%
print('Shape of Array 1-',arr1.shape)
print('Shape of Array 2-',arr2.shape)
# Out:
# Shape of Array 1- (2, 5)
# Shape of Array 2- (2,)

# %%
print('Type of Array 1-',arr1.dtype)
print('Type of Array 2-',arr2.dtype)
# Out:
# Type of Array 1- float64
# Type of Array 2- object

# %%
print('Size ',arr1.itemsize)
# Out:
# Size  8

# %%
print('number of elements ',arr1.size)
# Out:
# number of elements  10

# %%
print(arr1[0, 2])
print(arr1[0, 1:-1:2])
# Out:
# 5.0
# [6. 8.]

# %%
print(np.random.rand(4,2))
# Out:
# [[0.81894798 0.06587462]
#  [0.84073527 0.27965363]
#  [0.96729535 0.279023  ]
#  [0.9752143  0.00876407]]
