# %% [markdown]
# Mohammed Danish Ansari

# %%
#import

import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows',251)

# %% [markdown]
# Creation of DataFrame

# %%
dataframe = {'name':['Danish','Varun','PK','Muddasir'],'age':[17,20,19,21],'gamer level':[8.5,8.8,9.9,0.69]}

# %%
df = pd.DataFrame(dataframe)
print(df)
# Out:
#        name  age  gamer level
# 0    Danish   17         8.50
# 1     Varun   20         8.80
# 2        PK   19         9.90
# 3  Muddasir   21         0.69

# %% [markdown]
# Saving the dataframe to csv file

# %%
df.to_csv("gamerness.csv", index=False)

# %% [markdown]
# Reading Data from csv file

# %%
df = pd.read_csv("gamerness.csv")
print(df)
# Out:
#        name  age  gamer level
# 0    Danish   17         8.50
# 1     Varun   20         8.80
# 2        PK   19         9.90
# 3  Muddasir   21         0.69

# %% [markdown]
# Acessing and Manipulating Data

# %%
df = pd.read_csv('07-09-2021-TO-06-09-2022TATASTEELALLN.csv')

# %%
rows, columns = df.shape
print('rows',rows)
print('columns',columns)
# Out:
# rows 251
# columns 15

# %%
## Head prints first n number of rows
print(df.head(5))

## Head prints first n number of columns
print(df.tail(3))
# Out:
#       Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  TATASTEEL     EQ  07-Sep-21     1437.00      1444.0     1459.00    1420.65
# 1  TATASTEEL     EQ  08-Sep-21     1428.70      1426.0     1442.65    1418.60
# 2  TATASTEEL     EQ  09-Sep-21     1429.85      1420.0     1451.95    1420.00
# 3  TATASTEEL     EQ  13-Sep-21     1447.00      1447.0     1472.00    1436.50
# 4  TATASTEEL     EQ  14-Sep-21     1463.45      1476.0     1476.00    1449.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      1421.5      1428.70        1439.40                6352717
# 1      1428.0      1429.85        1430.46                4676224
# 2      1446.9      1447.00        1441.08                5313030
# 3      1470.0      1463.45        1451.62                5670208
# 4      1451.4      1452.30        1461.40                5503767
#
#        Turnover  No. of Trades Deliverable Qty % Dly Qt to Traded Qty
# ...

# %%
## Slicing a Dataframe
print(df.iloc[0])
print(df.iloc[0,0:3])
# Out:
# Symbol                       TATASTEEL
# Series                              EQ
# Date                         07-Sep-21
# Prev Close                      1437.0
# Open Price                      1444.0
# High Price                      1459.0
# Low Price                      1420.65
# Last Price                      1421.5
# Close Price                     1428.7
# Average Price                   1439.4
# Total Traded Quantity          6352717
# Turnover                  9144123989.0
# No. of Trades                   145446
# Deliverable Qty                1169405
# % Dly Qt to Traded Qty           18.41
# Name: 0, dtype: object
# Symbol    TATASTEEL
# Series           EQ
# Date      07-Sep-21
# Name: 0, dtype: object

# %%
## Descibe
df.describe()
# Out:
#         Prev Close   Open Price   High Price    Low Price   Last Price  \
# count   251.000000   251.000000   251.000000   251.000000   251.000000
# mean   1072.170518  1066.663546  1081.638247  1047.364143  1062.246813
# std     352.313161   363.535946   368.222332   356.798670   361.549502
# min     100.350000    98.100000   102.000000    97.150000   100.200000
# 25%    1033.600000  1018.500000  1035.650000   998.400000  1014.250000
# 50%    1173.000000  1168.300000  1186.600000  1151.550000  1169.100000
# 75%    1296.625000  1302.000000  1317.900000  1273.450000  1295.500000
# max    1463.450000  1476.000000  1476.000000  1449.000000  1470.000000
#
#        Close Price  Average Price  Total Traded Quantity      Turnover  \
# count   251.000000     251.000000           2.510000e+02  2.510000e+02
# mean   1062.597012    1064.420080           1.495817e+07  9.653725e+09
# std     361.786357     362.525149           2.169669e+07  5.027487e+09
# ...

# %% [markdown]
# Pandas Numpy

# %%
df.head()
# Out:
#       Symbol Series       Date  Prev Close  Open Price  High Price  Low Price  \
# 0  TATASTEEL     EQ  07-Sep-21     1437.00      1444.0     1459.00    1420.65
# 1  TATASTEEL     EQ  08-Sep-21     1428.70      1426.0     1442.65    1418.60
# 2  TATASTEEL     EQ  09-Sep-21     1429.85      1420.0     1451.95    1420.00
# 3  TATASTEEL     EQ  13-Sep-21     1447.00      1447.0     1472.00    1436.50
# 4  TATASTEEL     EQ  14-Sep-21     1463.45      1476.0     1476.00    1449.00
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0      1421.5      1428.70        1439.40                6352717
# 1      1428.0      1429.85        1430.46                4676224
# 2      1446.9      1447.00        1441.08                5313030
# 3      1470.0      1463.45        1451.62                5670208
# 4      1451.4      1452.30        1461.40                5503767
#
#        Turnover  No. of Trades Deliverable Qty % Dly Qt to Traded Qty
# ...

# %%
df.columns
# Out:
# Index(['Symbol', 'Series', 'Date', 'Prev Close', 'Open Price', 'High Price',
#        'Low Price', 'Last Price', 'Close Price', 'Average Price',
#        'Total Traded Quantity', 'Turnover', 'No. of Trades', 'Deliverable Qty',
#        '% Dly Qt to Traded Qty'],
#       dtype='object')

# %%
df[["Date","Open Price","Close Price"]]
# Out:
#           Date  Open Price  Close Price
# 0    07-Sep-21     1444.00      1428.70
# 1    08-Sep-21     1426.00      1429.85
# 2    09-Sep-21     1420.00      1447.00
# 3    13-Sep-21     1447.00      1463.45
# 4    14-Sep-21     1476.00      1452.30
# ..         ...         ...          ...
# 246  30-Aug-22      106.50       108.30
# 247  01-Sep-22      107.00       106.40
# 248  02-Sep-22      107.00       105.50
# 249  05-Sep-22      106.05       106.90
# 250  06-Sep-22      107.40       108.60
#
# [251 rows x 3 columns]

# %% [markdown]
# Deleting Column as it contains duplicate values

# %%
del df["Symbol"]
del df["Series"]

# %% [markdown]
# Deleting Null values

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 0    07-Sep-21     1437.00     1444.00     1459.00    1420.65     1421.50
# 1    08-Sep-21     1428.70     1426.00     1442.65    1418.60     1428.00
# 2    09-Sep-21     1429.85     1420.00     1451.95    1420.00     1446.90
# 3    13-Sep-21     1447.00     1447.00     1472.00    1436.50     1470.00
# 4    14-Sep-21     1463.45     1476.00     1476.00    1449.00     1451.40
# 5    15-Sep-21     1452.30     1452.30     1463.70    1444.40     1453.05
# 6    16-Sep-21     1455.10     1460.00     1471.90    1431.25     1436.90
# 7    17-Sep-21     1436.75     1437.00     1440.30    1360.00     1382.80
# 8    20-Sep-21     1385.90     1350.00     1351.90    1247.35     1247.35
# 9    21-Sep-21     1253.10     1258.00     1296.90    1232.90     1296.50
# 10   22-Sep-21     1292.20     1299.40     1318.00    1283.10     1303.00
# 11   23-Sep-21     1305.80     1330.00     1339.45    1306.05     1315.50
# ...

# %% [markdown]
# Most Trades are in July and August 2022

# %%
df.sort_values("Total Traded Quantity", ascending=False).head()
# Out:
#           Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 225  29-Jul-22      100.35      103.00      109.30     102.15      107.80
# 224  28-Jul-22      959.40       98.10      102.00      97.15      100.20
# 226  01-Aug-22      107.60      110.50      111.45     106.15      108.25
# 235  12-Aug-22      109.10      109.35      112.90     108.80      112.80
# 229  04-Aug-22      107.05      107.50      109.50     106.05      107.60
#
#      Close Price  Average Price  Total Traded Quantity      Turnover  \
# 225       107.60         106.71              166959934  1.781604e+10
# 224       100.35          99.48              137156107  1.364434e+10
# 226       108.25         108.42              125365761  1.359219e+10
# 235       112.65         111.88               95942333  1.073361e+10
# 229       107.70         107.86               79526154  8.577818e+09
#
#      No. of Trades Deliverable Qty % Dly Qt to Traded Qty
# ...

# %% [markdown]
# Most Profitable closing prices where in September 21

# %%
df.sort_values("Close Price", ascending=False).head()
# Out:
#         Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 3  13-Sep-21     1447.00      1447.0     1472.00    1436.50     1470.00
# 5  15-Sep-21     1452.30      1452.3     1463.70    1444.40     1453.05
# 4  14-Sep-21     1463.45      1476.0     1476.00    1449.00     1451.40
# 2  09-Sep-21     1429.85      1420.0     1451.95    1420.00     1446.90
# 6  16-Sep-21     1455.10      1460.0     1471.90    1431.25     1436.90
#
#    Close Price  Average Price  Total Traded Quantity      Turnover  \
# 3      1463.45        1451.62                5670208  8.230985e+09
# 5      1455.10        1454.40                4417464  6.424749e+09
# 4      1452.30        1461.40                5503767  8.043210e+09
# 2      1447.00        1441.08                5313030  7.656487e+09
# 6      1436.75        1445.76                5606797  8.106102e+09
#
#    No. of Trades Deliverable Qty % Dly Qt to Traded Qty
# 3         133505         1810526                  31.93
# ...

# %% [markdown]
# Profitable Days

# %%
df['Profit'] = df['Open Price'] - df['Close Price']

# %%
df.sort_values("Profit", ascending=False).head()
# Out:
#           Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 8    20-Sep-21     1385.90      1350.0     1351.90    1247.35     1247.35
# 166  10-May-22     1252.25      1251.0     1254.65    1158.55     1161.25
# 175  23-May-22     1170.60      1097.0     1097.00    1001.55     1026.35
# 193  16-Jun-22      959.55       975.0      975.00     898.20      898.65
# 162  04-May-22     1295.20      1327.3     1330.00    1254.50     1266.00
#
#      Close Price  Average Price  Total Traded Quantity      Turnover  \
# 8        1253.10        1293.00               28238412  3.651238e+10
# 166      1164.90        1196.85               14553742  1.741867e+10
# 175      1022.95        1028.79               27388346  2.817696e+10
# 193       901.70         931.04               12274105  1.142772e+10
# 162      1261.35        1289.60               13837402  1.784473e+10
#
#      No. of Trades Deliverable Qty % Dly Qt to Traded Qty  Profit
# ...

# %% [markdown]
# Profitable Days

# %%
len( df.loc[df["Profit"] >= 1] )
# Out:
# 132

# %% [markdown]
# Loss Days

# %%
len( df.loc[df["Profit"] <= 1] )
# Out:
# 122

# %% [markdown]
# Filtering Date

# %%
df["Date"].head()
# Out:
# 0    07-Sep-21
# 1    08-Sep-21
# 2    09-Sep-21
# 3    13-Sep-21
# 4    14-Sep-21
# Name: Date, dtype: object

# %%
yum = df["Date"].str.split("-", n = 3, expand=True)

# %%
df.head()
# Out:
#         Date  Prev Close  Open Price  High Price  Low Price  Last Price  \
# 0  07-Sep-21     1437.00      1444.0     1459.00    1420.65      1421.5
# 1  08-Sep-21     1428.70      1426.0     1442.65    1418.60      1428.0
# 2  09-Sep-21     1429.85      1420.0     1451.95    1420.00      1446.9
# 3  13-Sep-21     1447.00      1447.0     1472.00    1436.50      1470.0
# 4  14-Sep-21     1463.45      1476.0     1476.00    1449.00      1451.4
#
#    Close Price  Average Price  Total Traded Quantity      Turnover  \
# 0      1428.70        1439.40                6352717  9.144124e+09
# 1      1429.85        1430.46                4676224  6.689153e+09
# 2      1447.00        1441.08                5313030  7.656487e+09
# 3      1463.45        1451.62                5670208  8.230985e+09
# 4      1452.30        1461.40                5503767  8.043210e+09
#
#    No. of Trades Deliverable Qty % Dly Qt to Traded Qty  Profit Dated Month  \
# ...

# %%
df["Dated"] = yum[0]
df["Month"] = yum[1]
df["Year"] = yum[2]

# %% [markdown]
# Most Profits Made in a Year

# %%
df.groupby(["Year"]).sum()
# Out:
#       Prev Close  Open Price  High Price  Low Price  Last Price  Close Price  \
# Year
# 21      101859.6   102276.05   103490.55  100372.05   101599.95    101650.00
# 22      167255.2   165456.50   168000.65  162516.35   165024.00    165061.85
#
#       Average Price  Total Traded Quantity      Turnover  No. of Trades  \
# Year
# 21        101926.04              665454860  8.418066e+11       15639382
# 22        165243.40             3089046177  1.581278e+12       36123816
#
#       Profit
# Year
# 21    626.05
# 22    394.65
