# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Basic Graph

# %%
x = [0,1,2,3,4]
y = [0,2,4,6,8]


plt.plot(x,y, label = '2x', color='red', linewidth=2,marker='.', markersize=12, markeredgecolor='blue')

plt.title('Our First Graph!', fontdict = {'fontname' : 'Comic Sans MS', 'fontsize': 20})
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])
plt.legend()
plt.savefig('mygraph2.png', dpi = 300)

plt.show()

# %%
subjects = ['Computers', 'Maths', 'Science']
marks_1 = [50,70,60]
marks_2 = [99,74,65]

plt.plot(subjects,marks_1, label = 'Xs Marks', marker ='.')
plt.plot(subjects,marks_2, label = 'Ys Marks', marker = 'x' )
plt.legend()
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.title('Marks Comparison')
plt.savefig('mygraph1.png', dpi = 300)

plt.show()

# %%
x2 = np.arange(0,4.5,0.5)
plt.title('Squares of X', fontdict = {'fontsize' : 15})
plt.plot(x2[:5],x2[:5]**2, 'r', label = 'X^2')
plt.plot(x2[4:],x2[4:]**2, 'r--')
plt.legend()
plt.savefig('mygraph.png', dpi = 300)
plt.show()

# %% [markdown]
# # Bar Chart

# %%
labels = ['A','B','C']
values = [1,4,2]

bars = plt.bar(labels,values)
patterns = ['/', 'O', '*']
for bar in bars:
    bar.set_hatch(patterns.pop(0))

plt.show()
