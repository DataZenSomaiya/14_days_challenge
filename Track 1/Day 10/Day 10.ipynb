# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips=sns.load_dataset("tips")
diamonds=sns.load_dataset("diamonds")
penguins=sns.load_dataset("penguins")
brain_networks=sns.load_dataset("brain_networks")
titanic=sns.load_dataset("titanic")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x="sex",y="tip",data=tips,palette="YlGnBu")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,hue="sex",palette="YlGnBu")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="tip",data=tips,hue="sex",dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="reg")

# %%
sns.jointplot(x="tip",y="total_bill",data=tips,kind="hex",cmap="YlGnBu")

# %%
sns.pairplot(titanic.select_dtypes(['number']),hue='pclass')

# %%
titanic.corr()
# Out:
#             survived    pclass       age     sibsp     parch      fare  \
# survived    1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass     -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age        -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp      -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch       0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare        0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000
# adult_male -0.557080  0.094035  0.280328 -0.253586 -0.349943 -0.182024
# alone      -0.203367  0.135207  0.198270 -0.584471 -0.583398 -0.271832
#
#             adult_male     alone
# survived     -0.557080 -0.203367
# pclass        0.094035  0.135207
# age           0.280328  0.198270
# sibsp        -0.253586 -0.584471
# parch        -0.349943 -0.583398
# fare         -0.182024 -0.271832
# adult_male    1.000000  0.404744
# alone         0.404744  1.000000

# %%
sns.heatmap(titanic.corr(),annot=True,cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
sns.clustermap(titanic.drop("sex", axis=1))
# Out:
# C:\Users\panda\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:657: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 sns.clustermap(titanic.drop("sex",axis=1))
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:1417, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1409     raise RuntimeError("clustermap requires scipy to be available")
#    1411 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1412                       row_colors=row_colors, col_colors=col_colors,
#    1413                       z_score=z_score, standard_scale=standard_scale,
#    1414                       mask=mask, dendrogram_ratio=dendrogram_ratio,
#    1415                       colors_ratio=colors_ratio, cbar_pos=cbar_pos)
# -> 1417 return plotter.plot(metric=metric, method=method,
#    1418                     colorbar_kws=cbar_kws,
#    1419                     row_cluster=row_cluster, col_cluster=col_cluster,
#    1420                     row_linkage=row_linkage, col_linkage=col_linkage,
#    1421                     tree_kws=tree_kws, **kwargs)
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:1226, in ClusterGrid.plot(self, metric, method, colorbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, tree_kws, **kws)
#    1222     kws.pop("square")
#    1224 colorbar_kws = {} if colorbar_kws is None else colorbar_kws
# -> 1226 self.plot_dendrograms(row_cluster, col_cluster, metric, method,
#    1227                       row_linkage=row_linkage, col_linkage=col_linkage,
#    1228                       tree_kws=tree_kws)
#    1229 try:
#    1230     xind = self.dendrogram_col.reordered_ind
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:1071, in ClusterGrid.plot_dendrograms(self, row_cluster, col_cluster, metric, method, row_linkage, col_linkage, tree_kws)
#    1067 def plot_dendrograms(self, row_cluster, col_cluster, metric, method,
#    1068                      row_linkage, col_linkage, tree_kws):
#    1069     # Plot the row dendrogram
#    1070     if row_cluster:
# -> 1071         self.dendrogram_row = dendrogram(
#    1072             self.data2d, metric=metric, method=method, label=False, axis=0,
#    1073             ax=self.ax_row_dendrogram, rotate=True, linkage=row_linkage,
#    1074             tree_kws=tree_kws
#    1075         )
#    1076     else:
#    1077         self.ax_row_dendrogram.set_xticks([])
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:784, in dendrogram(data, linkage, axis, label, metric, method, rotate, tree_kws, ax)
#     781 if _no_scipy:
#     782     raise RuntimeError("dendrogram requires scipy to be installed")
# --> 784 plotter = _DendrogramPlotter(data, linkage=linkage, axis=axis,
#     785                              metric=metric, method=method,
#     786                              label=label, rotate=rotate)
#     787 if ax is None:
#     788     ax = plt.gca()
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:592, in _DendrogramPlotter.__init__(self, data, linkage, metric, method, axis, label, rotate)
#     589 self.rotate = rotate
#     591 if linkage is None:
# --> 592     self.linkage = self.calculated_linkage
#     593 else:
#     594     self.linkage = linkage
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:659, in _DendrogramPlotter.calculated_linkage(self)
#     655         msg = ("Clustering large matrix with scipy. Installing "
#     656                "`fastcluster` may give better performance.")
#     657         warnings.warn(msg)
# --> 659 return self._calculate_linkage_scipy()
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\seaborn\matrix.py:627, in _DendrogramPlotter._calculate_linkage_scipy(self)
#     626 def _calculate_linkage_scipy(self):
# --> 627     linkage = hierarchy.linkage(self.array, method=self.method,
#     628                                 metric=self.metric)
#     629     return linkage
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\scipy\cluster\hierarchy.py:1046, in linkage(y, method, metric, optimal_ordering)
#    1043 if method not in _LINKAGE_METHODS:
#    1044     raise ValueError("Invalid method: {0}".format(method))
# -> 1046 y = _convert_to_double(np.asarray(y, order='c'))
#    1048 if y.ndim == 1:
#    1049     distance.is_valid_y(y, throw=True, name='y')
#
# File ~\PycharmProjects\pythonProject\First Program\venv\lib\site-packages\scipy\cluster\hierarchy.py:1572, in _convert_to_double(X)
#    1570 def _convert_to_double(X):
#    1571     if X.dtype != np.double:
# -> 1572         X = X.astype(np.double)
#    1573     if not X.flags.contiguous:
#    1574         X = X.copy()
#
# ValueError: could not convert string to float: 'S'
