# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#         Date  series    open    HIGH     LOW   PREV. CLOSE     ltp   close   \
# 0   25-Aug-22      EQ  107.05  107.90  105.75        106.55  106.50  106.25
# 1   24-Aug-22      EQ  107.55  108.15  105.75        107.60  106.30  106.55
# 2   23-Aug-22      EQ  104.20  108.25  103.50        105.05  107.90  107.60
# 3   22-Aug-22      EQ  109.50  109.60  104.70        110.05  105.20  105.05
# 4   19-Aug-22      EQ  112.55  112.90  109.55        112.55  109.75  110.05
# 5   18-Aug-22      EQ  112.50  113.00  111.40        112.50  112.70  112.55
# 6   17-Aug-22      EQ  113.50  113.50  112.25        113.00  112.40  112.50
# 7   16-Aug-22      EQ  113.70  113.70  111.10        112.65  113.00  113.00
# 8   12-Aug-22      EQ  109.35  112.90  108.80        109.10  112.80  112.65
# 9   11-Aug-22      EQ  110.30  110.65  108.60        109.20  109.00  109.10
# 10  10-Aug-22      EQ  107.90  109.90  106.50        107.20  109.20  109.20
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           22 non-null     object
#  1   series         22 non-null     object
#  2   open           22 non-null     float64
#  3   HIGH           22 non-null     float64
#  4   LOW            22 non-null     float64
#  5   PREV. CLOSE    22 non-null     float64
#  6   ltp            22 non-null     float64
#  7   close          22 non-null     float64
#  8   vwap           22 non-null     float64
#  9   52W H          22 non-null     object
#  10  52W L          22 non-null     float64
#  11  VOLUME         22 non-null     int64
#  12  VALUE          22 non-null     object
#  13  No of trades   22 non-null     int64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 2.5+ KB

# %%
t=df.dtypes

# %%
type(t)
# Out:
# pandas.core.series.Series

# %%
t
# Out:
# Date              object
# series            object
# open             float64
# HIGH             float64
# LOW              float64
# PREV. CLOSE      float64
# ltp              float64
# close            float64
# vwap             float64
# 52W H             object
# 52W L            float64
# VOLUME             int64
# VALUE             object
# No of trades       int64
# dtype: object

# %%
for x in range (0,13):
    print(t[x])
# Out:
# object
# object
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# object
# float64
# int64
# object

# %%
t[]
# Out:
# dtype('O')

# %%
df._get_value(10,'open')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'open'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data=pd.read_csv('nba.csv')

# %%
data
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
t=data.dtypes
print(t)
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
v=data._get_value(10,'Salary')

# %%
v
# Out:
# 2569260.0

# %%
t[1]
# Out:
# dtype('O')

# %%
newdf=data.copy()

# %%
newdf.columns=list("123456789")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35860/1660756340.py in <module>
# ----> 1 newdf.columns=list("123456789")
#
# TypeError: 'list' object is not callable

# %%
newdf
# Out:
#                  1               2     3    4     5     6      7  \
# 0    Avery Bradley  Boston Celtics   0.0   PG  25.0   6-2  180.0
# 1      Jae Crowder  Boston Celtics  99.0   SF  25.0   6-6  235.0
# 2     John Holland  Boston Celtics  30.0   SG  27.0   6-5  205.0
# 3      R.J. Hunter  Boston Celtics  28.0   SG  22.0   6-5  185.0
# 4    Jonas Jerebko  Boston Celtics   8.0   PF  29.0  6-10  231.0
# ..             ...             ...   ...  ...   ...   ...    ...
# 453   Shelvin Mack       Utah Jazz   8.0   PG  26.0   6-3  203.0
# 454      Raul Neto       Utah Jazz  25.0   PG  24.0   6-1  179.0
# 455   Tibor Pleiss       Utah Jazz  21.0    C  26.0   7-3  256.0
# 456    Jeff Withey       Utah Jazz  24.0    C  26.0   7-0  231.0
# 457            NaN             NaN   NaN  NaN   NaN   NaN    NaN
#
#                      8          9
# 0                Texas  7730337.0
# 1            Marquette  6796117.0
# 2    Boston University        NaN
# 3        Georgia State  1148640.0
# ...

# %%
q=newdf._get_value(10,"9")

# %%
q
# Out:
# 2569260.0

# %%
lit=['1','2','3','4','5','6','7','8','9']

# %%
q=newdf._get_value(10,list[8])

# %%
df.columns=list("ABCDEFGHIJKHLM")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_35860/3339641364.py in <module>
# ----> 1 df.columns=list("ABCDEFGHIJKHLM")
#
# TypeError: 'list' object is not callable
