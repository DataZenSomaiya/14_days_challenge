# %%
import pandas as pd

# %%
df=pd.read_csv("data.csv")

# %%
df
# Out:
#         Date  series    open    HIGH     LOW   PREV. CLOSE     ltp   close   \
# 0   25-Aug-22      EQ  107.05  107.90  105.75        106.55  106.50  106.25
# 1   24-Aug-22      EQ  107.55  108.15  105.75        107.60  106.30  106.55
# 2   23-Aug-22      EQ  104.20  108.25  103.50        105.05  107.90  107.60
# 3   22-Aug-22      EQ  109.50  109.60  104.70        110.05  105.20  105.05
# 4   19-Aug-22      EQ  112.55  112.90  109.55        112.55  109.75  110.05
# 5   18-Aug-22      EQ  112.50  113.00  111.40        112.50  112.70  112.55
# 6   17-Aug-22      EQ  113.50  113.50  112.25        113.00  112.40  112.50
# 7   16-Aug-22      EQ  113.70  113.70  111.10        112.65  113.00  113.00
# 8   12-Aug-22      EQ  109.35  112.90  108.80        109.10  112.80  112.65
# 9   11-Aug-22      EQ  110.30  110.65  108.60        109.20  109.00  109.10
# 10  10-Aug-22      EQ  107.90  109.90  106.50        107.20  109.20  109.20
# ...

# %%
newdf=df.copy()

# %%
df.columns
# Out:
# Index(['Date ', 'series ', 'open ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ',
#        'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ',
#        'No of trades '],
#       dtype='object')

# %%
newdf.columns=list("ABCDEFGHIJKLMN")

# %%
newdf
# Out:
#             A   B       C       D       E       F       G       H       I  \
# 0   25-Aug-22  EQ  107.05  107.90  105.75  106.55  106.50  106.25  106.98
# 1   24-Aug-22  EQ  107.55  108.15  105.75  107.60  106.30  106.55  106.69
# 2   23-Aug-22  EQ  104.20  108.25  103.50  105.05  107.90  107.60  106.67
# 3   22-Aug-22  EQ  109.50  109.60  104.70  110.05  105.20  105.05  106.79
# 4   19-Aug-22  EQ  112.55  112.90  109.55  112.55  109.75  110.05  111.08
# 5   18-Aug-22  EQ  112.50  113.00  111.40  112.50  112.70  112.55  112.33
# 6   17-Aug-22  EQ  113.50  113.50  112.25  113.00  112.40  112.50  112.85
# 7   16-Aug-22  EQ  113.70  113.70  111.10  112.65  113.00  113.00  112.55
# 8   12-Aug-22  EQ  109.35  112.90  108.80  109.10  112.80  112.65  111.88
# 9   11-Aug-22  EQ  110.30  110.65  108.60  109.20  109.00  109.10  109.49
# 10  10-Aug-22  EQ  107.90  109.90  106.50  107.20  109.20  109.20  108.23
# 11  08-Aug-22  EQ  107.85  108.15  106.70  107.35  107.25  107.20  107.35
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           22 non-null     object
#  1   series         22 non-null     object
#  2   open           22 non-null     float64
#  3   HIGH           22 non-null     float64
#  4   LOW            22 non-null     float64
#  5   PREV. CLOSE    22 non-null     float64
#  6   ltp            22 non-null     float64
#  7   close          22 non-null     float64
#  8   vwap           22 non-null     float64
#  9   52W H          22 non-null     object
#  10  52W L          22 non-null     float64
#  11  VOLUME         22 non-null     int64
#  12  VALUE          22 non-null     object
#  13  No of trades   22 non-null     int64
# dtypes: float64(8), int64(2), object(4)
# memory usage: 2.5+ KB

# %%
newdf._get_value(10,"D")
# Out:
# 109.9

# %%
t=newdf.dtypes

# %%
t
# Out:
# A     object
# B     object
# C    float64
# D    float64
# E    float64
# F    float64
# G    float64
# H    float64
# I    float64
# J     object
# K    float64
# L      int64
# M     object
# N      int64
# dtype: object

# %%
t[0]==int
# Out:
# False

# %%
attri=['A','B','C','D','E','F','H','I','J','K','L','M','N']

# %%
at=[]

# %%
for col in df.columns:
    at.append(col)
    v=df._get_value(10,col)
    print(v)
# Out:
# 10-Aug-22
# EQ
# 107.9
# 109.9
# 106.5
# 107.2
# 109.2
# 109.2
# 108.23
# 1,534.50
# 97.15
# 73880698
# 7,99,64,57,230.30
# 241058

# %%
at
# Out:
# ['Date ',
#  'series ',
#  'open ',
#  'HIGH ',
#  'LOW ',
#  'PREV. CLOSE ',
#  'ltp ',
#  'close ',
#  'vwap ',
#  '52W H ',
#  '52W L ',
#  'VOLUME ',
#  'VALUE ',
#  'No of trades ']

# %%
t[0]
# Out:
# dtype('O')

# %%
t=df.dtypes

# %%
t
# Out:
# Date              object
# series            object
# open             float64
# HIGH             float64
# LOW              float64
# PREV. CLOSE      float64
# ltp              float64
# close            float64
# vwap             float64
# 52W H             object
# 52W L            float64
# VOLUME             int64
# VALUE             object
# No of trades       int64
# dtype: object

# %%
for x in range (13,-1,-1):
    if t[x]==object:
        print("*")
        del at[x]
# Out:
# *
# *
# *
# *

# %%
at
# Out:
# ['open ',
#  'HIGH ',
#  'LOW ',
#  'PREV. CLOSE ',
#  'ltp ',
#  'close ',
#  'vwap ',
#  '52W L ',
#  'VOLUME ',
#  'No of trades ']

# %%
Summation=0
mean=[]
for y in at:
    for x in range (0,22):
        a=df._get_value(x,y)
        Summation=a+Summation
    me=Summation/22
    Summation=0
    mean.append(me)

# %%
mean
# Out:
# [223.44090909090912,
#  226.80227272727276,
#  220.35454545454547,
#  261.6545454545454,
#  224.1,
#  223.93636363636367,
#  223.88545454545454,
#  196.675,
#  67109349.63636364,
#  278619.13636363635]

# %%
df.mean()
# Out:
# C:\Users\venee\AppData\Local\Temp/ipykernel_9732/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# open             2.234409e+02
# HIGH             2.268023e+02
# LOW              2.203545e+02
# PREV. CLOSE      2.616545e+02
# ltp              2.241000e+02
# close            2.239364e+02
# vwap             2.238855e+02
# 52W L            1.966750e+02
# VOLUME           6.710935e+07
# No of trades     2.786191e+05
# dtype: float64

# %%
def bubbleSort(array):
    
  # loop to access each array element
  for i in range(len(array)):

    # loop to compare array elements
    for j in range(0, len(array) - i - 1):

      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:

        # swapping elements if elements
        # are not in the intended order
        temp = array[j]
        array[j] = array[j+1]
        array[j+1] = temp


data = [-2, 45, 0, 11, -9]

bubbleSort(data)

print('Sorted Array in Ascending Order:')
print(data)
# Out:
# Sorted Array in Ascending Order:
# [-9, -2, 0, 11, 45]

# %%
middle=0
aa=[]
median=[]
mode=[]
for y in at:
    for x in range (0,22):
        a=df._get_value(x,y)
        aa.append(a)
    bubbleSort(aa)
    count=0
    mod=0
    tempp=0
    for x in aa:
        for y in range(count+1,22):
            if x==aa[y]:
                temp = temp+1
        count=count+1
        if temp>0:
            if temp>tempp:
                tempp=temp
                mod=x
        temp=0
    mode.append(mod)        
    middle=(aa[10]+aa[11])/2
    aa=[]
    median.append(middle)

# %%
median
# Out:
# [108.675,
#  109.75,
#  106.6,
#  108.675,
#  108.075,
#  107.975,
#  108.135,
#  97.15,
#  63182108.5,
#  237183.5]

# %%
df.median()
# Out:
# C:\Users\venee\AppData\Local\Temp/ipykernel_9732/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# open             1.086750e+02
# HIGH             1.097500e+02
# LOW              1.066000e+02
# PREV. CLOSE      1.086750e+02
# ltp              1.080750e+02
# close            1.079750e+02
# vwap             1.081350e+02
# 52W L            9.715000e+01
# VOLUME           6.318211e+07
# No of trades     2.371835e+05
# dtype: float64

# %%
mode
# Out:
# [0, 108.15, 105.75, 107.6, 0, 107.6, 0, 97.15, 0, 0]

# %%
df.mode()
# Out:
#         Date  series    open    HIGH     LOW   PREV. CLOSE     ltp   close   \
# 0   01-Aug-22      EQ   98.10  108.15  105.75         107.6  100.20   107.6
# 1   02-Aug-22     NaN  103.00  112.90     NaN           NaN  105.20     NaN
# 2   03-Aug-22     NaN  104.20     NaN     NaN           NaN  106.30     NaN
# 3   04-Aug-22     NaN  107.00     NaN     NaN           NaN  106.50     NaN
# 4   05-Aug-22     NaN  107.05     NaN     NaN           NaN  106.90     NaN
# 5   08-Aug-22     NaN  107.50     NaN     NaN           NaN  107.10     NaN
# 6   10-Aug-22     NaN  107.55     NaN     NaN           NaN  107.25     NaN
# 7   11-Aug-22     NaN  107.65     NaN     NaN           NaN  107.30     NaN
# 8   12-Aug-22     NaN  107.85     NaN     NaN           NaN  107.60     NaN
# 9   16-Aug-22     NaN  107.90     NaN     NaN           NaN  107.80     NaN
# 10  17-Aug-22     NaN  108.00     NaN     NaN           NaN  107.90     NaN
# ...

# %%
final=pd.DataFrame(list(zip(at,mean,mode,median)),columns=['Attributes','Mean','Mode','Median'])

# %%
final
# Out:
#       Attributes          Mean    Mode        Median
# 0          open   2.234409e+02    0.00  1.086750e+02
# 1          HIGH   2.268023e+02  108.15  1.097500e+02
# 2           LOW   2.203545e+02  105.75  1.066000e+02
# 3   PREV. CLOSE   2.616545e+02  107.60  1.086750e+02
# 4           ltp   2.241000e+02    0.00  1.080750e+02
# 5         close   2.239364e+02  107.60  1.079750e+02
# 6          vwap   2.238855e+02    0.00  1.081350e+02
# 7         52W L   1.966750e+02   97.15  9.715000e+01
# 8        VOLUME   6.710935e+07    0.00  6.318211e+07
# 9  No of trades   2.786191e+05    0.00  2.371835e+05

# %%
import pandas as pd
df=pd.read_csv("data.csv")
t=df.dtypes
at=[]
for col in df.columns:
    at.append(col)
for x in range (13,-1,-1):
    if t[x]==object:
        del at[x]
Summation=0
mean=[]
for y in at:
    for x in range (0,22):
        a=df._get_value(x,y)
        Summation=a+Summation
    me=Summation/22
    Summation=0
    mean.append(me)
def bubbleSort(array):
    
  # loop to access each array element
  for i in range(len(array)):

    # loop to compare array elements
    for j in range(0, len(array) - i - 1):

      # compare two adjacent elements
      # change > to < to sort in descending order
      if array[j] > array[j + 1]:

        # swapping elements if elements
        # are not in the intended order
        temp = array[j]
        array[j] = array[j+1]
        array[j+1] = temp
middle=0
aa=[]
median=[]
mode=[]
for y in at:
    for x in range (0,22):
        a=df._get_value(x,y)
        aa.append(a)
    bubbleSort(aa)
    count=0
    mod=0
    tempp=0
    for x in aa:
        for y in range(count+1,22):
            if x==aa[y]:
                temp = temp+1
        count=count+1
        if temp>0:
            if temp>tempp:
                tempp=temp
                mod=x
        temp=0
    mode.append(mod)        
    middle=(aa[10]+aa[11])/2
    aa=[]
    median.append(middle)
final=pd.DataFrame(list(zip(at,mean,mode,median)),columns=['Attributes','Mean','Mode','Median'])
print(final)
# Out:
#       Attributes          Mean    Mode        Median
# 0          open   2.234409e+02    0.00  1.086750e+02
# 1          HIGH   2.268023e+02  108.15  1.097500e+02
# 2           LOW   2.203545e+02  105.75  1.066000e+02
# 3   PREV. CLOSE   2.616545e+02  107.60  1.086750e+02
# 4           ltp   2.241000e+02    0.00  1.080750e+02
# 5         close   2.239364e+02  107.60  1.079750e+02
# 6          vwap   2.238855e+02    0.00  1.081350e+02
# 7         52W L   1.966750e+02   97.15  9.715000e+01
# 8        VOLUME   6.710935e+07    0.00  6.318211e+07
# 9  No of trades   2.786191e+05    0.00  2.371835e+05
